# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 2.8 (c:\users\rgkal\anaconda3\lib\site-packages), Requirement.parse('cryptography>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# Ready to use Azure ML 1.35.0 to work with workspace1

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.887
# AUC: 0.8736230658241703
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# workspaceworkingdirectory - Default = False
# workspaceartifactstore - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data\1.csv
# Uploaded batch-data\1.csv, 1 files out of an estimated total of 100
# Uploading batch-data\10.csv
# Uploaded batch-data\10.csv, 2 files out of an estimated total of 100
# Uploading batch-data\100.csv
# Uploaded batch-data\100.csv, 3 files out of an estimated total of 100
# Uploading batch-data\11.csv
# Uploaded batch-data\11.csv, 4 files out of an estimated total of 100
# Uploading batch-data\12.csv
# Uploaded batch-data\12.csv, 5 files out of an estimated total of 100
# Uploading batch-data\13.csv
# Uploaded batch-data\13.csv, 6 files out of an estimated total of 100
# Uploading batch-data\14.csv
# Uploaded batch-data\14.csv, 7 files out of an estimated total of 100
# Uploading batch-data\15.csv
# Uploaded batch-data\15.csv, 8 files out of an estimated total of 100
# Uploading batch-data\16.csv
# Uploaded batch-data\16.csv, 9 files out of an estimated total of 100
# Uploading batch-data\17.csv
# Uploaded batch-data\17.csv, 10 files out of an estimated total of 100
# Uploading batch-data\18.csv
# Uploaded batch-data\18.csv, 11 files out of an estimated total of 100
# Uploading batch-data\19.csv
# Uploaded batch-data\19.csv, 12 files out of an estimated total of 100
# Uploading batch-data\2.csv
# Uploaded batch-data\2.csv, 13 files out of an estimated total of 100
# Uploading batch-data\21.csv
# Uploaded batch-data\21.csv, 14 files out of an estimated total of 100
# Uploading batch-data\22.csv
# Uploaded batch-data\22.csv, 15 files out of an estimated total of 100
# Uploading batch-data\23.csv
# Uploaded batch-data\23.csv, 16 files out of an estimated total of 100
# Uploading batch-data\24.csv
# Uploaded batch-data\24.csv, 17 files out of an estimated total of 100
# Uploading batch-data\25.csv
# Uploaded batch-data\25.csv, 18 files out of an estimated total of 100
# Uploading batch-data\26.csv
# Uploaded batch-data\26.csv, 19 files out of an estimated total of 100
# Uploading batch-data\27.csv
# Uploaded batch-data\27.csv, 20 files out of an estimated total of 100
# Uploading batch-data\28.csv
# Uploaded batch-data\28.csv, 21 files out of an estimated total of 100
# Uploading batch-data\29.csv
# Uploaded batch-data\29.csv, 22 files out of an estimated total of 100
# Uploading batch-data\3.csv
# Uploaded batch-data\3.csv, 23 files out of an estimated total of 100
# Uploading batch-data\30.csv
# Uploaded batch-data\30.csv, 24 files out of an estimated total of 100
# Uploading batch-data\32.csv
# Uploaded batch-data\32.csv, 25 files out of an estimated total of 100
# Uploading batch-data\33.csv
# Uploaded batch-data\33.csv, 26 files out of an estimated total of 100
# Uploading batch-data\34.csv
# Uploaded batch-data\34.csv, 27 files out of an estimated total of 100
# Uploading batch-data\35.csv
# Uploaded batch-data\35.csv, 28 files out of an estimated total of 100
# Uploading batch-data\36.csv
# Uploaded batch-data\36.csv, 29 files out of an estimated total of 100
# Uploading batch-data\37.csv
# Uploaded batch-data\37.csv, 30 files out of an estimated total of 100
# Uploading batch-data\38.csv
# Uploaded batch-data\38.csv, 31 files out of an estimated total of 100
# Uploading batch-data\39.csv
# Uploaded batch-data\39.csv, 32 files out of an estimated total of 100
# Uploading batch-data\4.csv
# Uploaded batch-data\4.csv, 33 files out of an estimated total of 100
# Uploading batch-data\40.csv
# Uploaded batch-data\40.csv, 34 files out of an estimated total of 100
# Uploading batch-data\41.csv
# Uploaded batch-data\41.csv, 35 files out of an estimated total of 100
# Uploading batch-data\42.csv
# Uploaded batch-data\42.csv, 36 files out of an estimated total of 100
# Uploading batch-data\20.csv
# Uploaded batch-data\20.csv, 37 files out of an estimated total of 100
# Uploading batch-data\31.csv
# Uploaded batch-data\31.csv, 38 files out of an estimated total of 100
# Uploading batch-data\43.csv
# Uploaded batch-data\43.csv, 39 files out of an estimated total of 100
# Uploading batch-data\44.csv
# Uploaded batch-data\44.csv, 40 files out of an estimated total of 100
# Uploading batch-data\45.csv
# Uploaded batch-data\45.csv, 41 files out of an estimated total of 100
# Uploading batch-data\46.csv
# Uploaded batch-data\46.csv, 42 files out of an estimated total of 100
# Uploading batch-data\47.csv
# Uploaded batch-data\47.csv, 43 files out of an estimated total of 100
# Uploading batch-data\48.csv
# Uploaded batch-data\48.csv, 44 files out of an estimated total of 100
# Uploading batch-data\49.csv
# Uploaded batch-data\49.csv, 45 files out of an estimated total of 100
# Uploading batch-data\5.csv
# Uploaded batch-data\5.csv, 46 files out of an estimated total of 100
# Uploading batch-data\50.csv
# Uploaded batch-data\50.csv, 47 files out of an estimated total of 100
# Uploading batch-data\51.csv
# Uploaded batch-data\51.csv, 48 files out of an estimated total of 100
# Uploading batch-data\52.csv
# Uploaded batch-data\52.csv, 49 files out of an estimated total of 100
# Uploading batch-data\53.csv
# Uploaded batch-data\53.csv, 50 files out of an estimated total of 100
# Uploading batch-data\54.csv
# Uploaded batch-data\54.csv, 51 files out of an estimated total of 100
# Uploading batch-data\55.csv
# Uploaded batch-data\55.csv, 52 files out of an estimated total of 100
# Uploading batch-data\56.csv
# Uploaded batch-data\56.csv, 53 files out of an estimated total of 100
# Uploading batch-data\57.csv
# Uploaded batch-data\57.csv, 54 files out of an estimated total of 100
# Uploading batch-data\58.csv
# Uploaded batch-data\58.csv, 55 files out of an estimated total of 100
# Uploading batch-data\59.csv
# Uploaded batch-data\59.csv, 56 files out of an estimated total of 100
# Uploading batch-data\6.csv
# Uploaded batch-data\6.csv, 57 files out of an estimated total of 100
# Uploading batch-data\60.csv
# Uploaded batch-data\60.csv, 58 files out of an estimated total of 100
# Uploading batch-data\61.csv
# Uploaded batch-data\61.csv, 59 files out of an estimated total of 100
# Uploading batch-data\62.csv
# Uploaded batch-data\62.csv, 60 files out of an estimated total of 100
# Uploading batch-data\63.csv
# Uploaded batch-data\63.csv, 61 files out of an estimated total of 100
# Uploading batch-data\64.csv
# Uploaded batch-data\64.csv, 62 files out of an estimated total of 100
# Uploading batch-data\65.csv
# Uploaded batch-data\65.csv, 63 files out of an estimated total of 100
# Uploading batch-data\66.csv
# Uploaded batch-data\66.csv, 64 files out of an estimated total of 100
# Uploading batch-data\67.csv
# Uploaded batch-data\67.csv, 65 files out of an estimated total of 100
# Uploading batch-data\68.csv
# Uploaded batch-data\68.csv, 66 files out of an estimated total of 100
# Uploading batch-data\69.csv
# Uploaded batch-data\69.csv, 67 files out of an estimated total of 100
# Uploading batch-data\7.csv
# Uploaded batch-data\7.csv, 68 files out of an estimated total of 100
# Uploading batch-data\70.csv
# Uploaded batch-data\70.csv, 69 files out of an estimated total of 100
# Uploading batch-data\71.csv
# Uploaded batch-data\71.csv, 70 files out of an estimated total of 100
# Uploading batch-data\72.csv
# Uploaded batch-data\72.csv, 71 files out of an estimated total of 100
# Uploading batch-data\73.csv
# Uploaded batch-data\73.csv, 72 files out of an estimated total of 100
# Uploading batch-data\74.csv
# Uploaded batch-data\74.csv, 73 files out of an estimated total of 100
# Uploading batch-data\75.csv
# Uploaded batch-data\75.csv, 74 files out of an estimated total of 100
# Uploading batch-data\76.csv
# Uploaded batch-data\76.csv, 75 files out of an estimated total of 100
# Uploading batch-data\77.csv
# Uploaded batch-data\77.csv, 76 files out of an estimated total of 100
# Uploading batch-data\78.csv
# Uploaded batch-data\78.csv, 77 files out of an estimated total of 100
# Uploading batch-data\79.csv
# Uploaded batch-data\79.csv, 78 files out of an estimated total of 100
# Uploading batch-data\8.csv
# Uploaded batch-data\8.csv, 79 files out of an estimated total of 100
# Uploading batch-data\80.csv
# Uploaded batch-data\80.csv, 80 files out of an estimated total of 100
# Uploading batch-data\81.csv
# Uploaded batch-data\81.csv, 81 files out of an estimated total of 100
# Uploading batch-data\82.csv
# Uploaded batch-data\82.csv, 82 files out of an estimated total of 100
# Uploading batch-data\83.csv
# Uploaded batch-data\83.csv, 83 files out of an estimated total of 100
# Uploading batch-data\84.csv
# Uploaded batch-data\84.csv, 84 files out of an estimated total of 100
# Uploading batch-data\85.csv
# Uploaded batch-data\85.csv, 85 files out of an estimated total of 100
# Uploading batch-data\86.csv
# Uploaded batch-data\86.csv, 86 files out of an estimated total of 100
# Uploading batch-data\87.csv
# Uploaded batch-data\87.csv, 87 files out of an estimated total of 100
# Uploading batch-data\88.csv
# Uploaded batch-data\88.csv, 88 files out of an estimated total of 100
# Uploading batch-data\89.csv
# Uploaded batch-data\89.csv, 89 files out of an estimated total of 100
# Uploading batch-data\9.csv
# Uploaded batch-data\9.csv, 90 files out of an estimated total of 100
# Uploading batch-data\90.csv
# Uploaded batch-data\90.csv, 91 files out of an estimated total of 100
# Uploading batch-data\91.csv
# Uploaded batch-data\91.csv, 92 files out of an estimated total of 100
# Uploading batch-data\92.csv
# Uploaded batch-data\92.csv, 93 files out of an estimated total of 100
# Uploading batch-data\93.csv
# Uploaded batch-data\93.csv, 94 files out of an estimated total of 100
# Uploading batch-data\94.csv
# Uploaded batch-data\94.csv, 95 files out of an estimated total of 100
# Uploading batch-data\95.csv
# Uploaded batch-data\95.csv, 96 files out of an estimated total of 100
# Uploading batch-data\96.csv
# Uploaded batch-data\96.csv, 97 files out of an estimated total of 100
# Uploading batch-data\97.csv
# Uploaded batch-data\97.csv, 98 files out of an estimated total of 100
# Uploading batch-data\98.csv
# Uploaded batch-data\98.csv, 99 files out of an estimated total of 100
# Uploading batch-data\99.csv
# Uploaded batch-data\99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "compcluster1"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig
from azureml.core.runconfig import DockerConfiguration

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [c2aed05f][4e9c97b8-a752-48ca-b6df-22fbdb9fd33a], (This step will run and generate new outputs)
# Submitted PipelineRun 32fb58b5-bb67-4a9a-adff-905e0166f4f5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/32fb58b5-bb67-4a9a-adff-905e0166f4f5?wsid=/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourcegroups/resgrp1/workspaces/workspace1&tid=378009d7-cd7a-4659-9bbc-c3eae57b738b
# PipelineRunId: 32fb58b5-bb67-4a9a-adff-905e0166f4f5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/32fb58b5-bb67-4a9a-adff-905e0166f4f5?wsid=/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourcegroups/resgrp1/workspaces/workspace1&tid=378009d7-cd7a-4659-9bbc-c3eae57b738b
# PipelineRun Status: Running
#
#
# StepRunId: 138324b9-f103-49a8-8c6b-028cebef89bd
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/138324b9-f103-49a8-8c6b-028cebef89bd?wsid=/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourcegroups/resgrp1/workspaces/workspace1&tid=378009d7-cd7a-4659-9bbc-c3eae57b738b
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/10/21 19:45:48 Downloading source code...
# 2021/10/21 19:45:49 Finished downloading source code
# 2021/10/21 19:45:49 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/10/21 19:45:49 Successfully set up Docker network: acb_default_network
# 2021/10/21 19:45:49 Setting up Docker configuration...
# 2021/10/21 19:45:50 Successfully set up Docker configuration
# 2021/10/21 19:45:50 Logging in to registry: c872935793314557aea7f994311d847d.azurecr.io
# 2021/10/21 19:45:51 Successfully logged into c872935793314557aea7f994311d847d.azurecr.io
# 2021/10/21 19:45:51 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/21 19:45:51 Scanning for dependencies...
# 2021/10/21 19:45:51 Successfully scanned dependencies
# 2021/10/21 19:45:51 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# e4ca327ec0e7: Already exists
# f0fb8b64b41b: Pulling fs layer
# e43ee38068bf: Pulling fs layer
# 409df78264bc: Pulling fs layer
# a2eb44ae9dc0: Pulling fs layer
# b8ff7afa1c52: Pulling fs layer
# d92dd21f7e9a: Pulling fs layer
# 965946e36f3d: Pulling fs layer
# 9d3ce4a2dac8: Pulling fs layer
# b8ff7afa1c52: Waiting
# d92dd21f7e9a: Waiting
# 965946e36f3d: Waiting
# 9d3ce4a2dac8: Waiting
# a2eb44ae9dc0: Waiting
# 409df78264bc: Verifying Checksum
# 409df78264bc: Download complete
# e43ee38068bf: Verifying Checksum
# e43ee38068bf: Download complete
# b8ff7afa1c52: Verifying Checksum
# b8ff7afa1c52: Download complete
# a2eb44ae9dc0: Verifying Checksum
# a2eb44ae9dc0: Download complete
# d92dd21f7e9a: Verifying Checksum
# d92dd21f7e9a: Download complete
# 9d3ce4a2dac8: Verifying Checksum
# 9d3ce4a2dac8: Download complete
# 965946e36f3d: Verifying Checksum
# f0fb8b64b41b: Verifying Checksum
# f0fb8b64b41b: Download complete
# f0fb8b64b41b: Pull complete
# e43ee38068bf: Pull complete
# 409df78264bc: Pull complete
# a2eb44ae9dc0: Pull complete
# b8ff7afa1c52: Pull complete
# d92dd21f7e9a: Pull complete
# 965946e36f3d: Pull complete
# 9d3ce4a2dac8: Pull complete
# Digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1@sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#  ---> 9e882d6546b4
# Step 2/19 : USER root
#  ---> Running in 3aa90c9c02b1
# Removing intermediate container 3aa90c9c02b1
#  ---> 24317bd40947
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in e015a9daa78a
# Removing intermediate container e015a9daa78a
#  ---> 75128ec207b2
# Step 4/19 : WORKDIR /
#  ---> Running in 3378813e4721
# Removing intermediate container 3378813e4721
#  ---> e98226768f8d
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 26696ab77563
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 9333605a57eb
# Removing intermediate container 9333605a57eb
#  ---> de3f7586abc2
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 9bfc6c4cb95f
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c52715bd9012
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# ca-certificates-2021 | 116 KB    |            |   0%
# ca-certificates-2021 | 116 KB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ####3      |  44%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ##6        |  26%
# python-3.6.2         | 23.6 MB   | ########6  |  86%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# wheel-0.37.0         | 33 KB     |            |   0%
# wheel-0.37.0         | 33 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 7          |   7%
# mkl-2020.2           | 138.3 MB  | #8         |  18%
# mkl-2020.2           | 138.3 MB  | ##8        |  29%
# mkl-2020.2           | 138.3 MB  | ###9       |  39%
# mkl-2020.2           | 138.3 MB  | ####9      |  49%
# mkl-2020.2           | 138.3 MB  | #####9     |  59%
# mkl-2020.2           | 138.3 MB  | ######8    |  69%
# mkl-2020.2           | 138.3 MB  | #######7   |  78%
# mkl-2020.2           | 138.3 MB  | ########6  |  87%
# mkl-2020.2           | 138.3 MB  | #########6 |  97%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.0fo5wtz4.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.35.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.2-py3-none-any.whl (38 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.35.0
#   Downloading azureml_dataset_runtime-1.35.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-core~=1.35.0
#   Downloading azureml_core-1.35.0-py3-none-any.whl (2.2 MB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.0fo5wtz4.requirements.txt (line 1)) (58.0.4)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting ruamel.yaml<=0.17.16,>=0.17.10
#   Downloading ruamel.yaml-0.17.16-py3-none-any.whl (109 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.35.0->azureml-defaults->-r /azureml-environment-setup/condaenv.0fo5wtz4.requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.35.0->azureml-defaults->-r /azureml-environment-setup/condaenv.0fo5wtz4.requirements.txt (line 1)) (1.19.2)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.24.0a,>=2.23.0a
#   Downloading azureml_dataprep-2.23.2-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex~=1.21.0dev0
#   Downloading azureml_dataprep_rslex-1.21.2-cp36-cp36m-manylinux2010_x86_64.whl (13.0 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.15.0-py2.py3-none-any.whl (77 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.35.0->azureml-defaults->-r /azureml-environment-setup/condaenv.0fo5wtz4.requirements.txt (line 1)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.1.1-py2.py3-none-any.whl (95 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.3.0-py2.py3-none-any.whl (154 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=fdb2babfeacc36a6acefe6f4703cd9be4233c53dee669c9b7f8ae461d837f447
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=e85ee8fe0508f6892ce161baf2f684c30456740ee01a2a08e80567a353147c2c
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69942 sha256=b3502ffe491a93f6a563bfd8d416fc3292ca3a28e1346e9955c6040927ab33b1
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=c1c59bb02e70a0209ab0dc37cee14918e78ec382dcbd272a46a277aa8fffdb2d
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, typing-extensions, pyasn1, portalocker, oauthlib, msal, zipp, rsa, requests-oauthlib, python-dateutil, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, msrest, MarkupSafe, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, werkzeug, websocket-client, ruamel.yaml.clib, pytz, pyopenssl, pyarrow, opencensus-context, msrestazure, Jinja2, jeepney, itsdangerous, google-api-core, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, jsonpickle, jmespath, inference-schema, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, opencensus-ext-azure, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.2 MarkupSafe-2.0.1 PyJWT-2.3.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.19.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.35.0 azureml-dataprep-2.23.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.21.2 azureml-dataset-runtime-1.35.0 azureml-defaults-1.35.0 azureml-inference-server-http-0.3.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.4 cffi-1.15.0 charset-normalizer-2.0.7 click-8.0.3 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-2.1.1 google-auth-2.3.0 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.3 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.15.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.8.0 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.19.0 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.2 pytz-2021.3 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.16 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c52715bd9012
#  ---> 232d01a10542
# Step 9/19 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in 9169173636ac
# Removing intermediate container 9169173636ac
#  ---> 2dc3191dbc23
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> fca4848cb658
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 3ba01a5ecd6c
# Copying environment context
# Removing intermediate container 3ba01a5ecd6c
#  ---> 8a4e31d6516e
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> be7a0174a337
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 580ee0f6d0a9
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 580ee0f6d0a9
#  ---> 3b33a8798b44
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in a4b11eff0382
# Removing intermediate container a4b11eff0382
#  ---> d61f342682dd
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in ad30fcc75e68
# Removing intermediate container ad30fcc75e68
#  ---> de6b7cd21b58
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 450d49b73ceb
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in f15db2f9bd52
# Removing intermediate container f15db2f9bd52
#  ---> a16917a909e3
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7a4e6a257ea2
# Removing intermediate container 7a4e6a257ea2
#  ---> 68cdf5b47d16
# Step 19/19 : CMD ["bash"]
#  ---> Running in e5c8644b3b20
# Removing intermediate container e5c8644b3b20
#  ---> 8ecaa9e4a121
# Successfully built 8ecaa9e4a121
# Successfully tagged c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:latest
# Successfully tagged c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:1
# 2021/10/21 19:47:41 Successfully executed container: acb_step_0
# 2021/10/21 19:47:41 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/21 19:47:41 Pushing image: c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:1, attempt 1
# The push refers to repository [c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c]
# 182b9829a170: Preparing
# 1e7ce649d2bc: Preparing
# b6223d9220d5: Preparing
# 4f16a913b5a6: Preparing
# 29edf9db0f9b: Preparing
# fb5dda257106: Preparing
# a9afd6424baa: Preparing
# b2684f70a5a4: Preparing
# c1c430b6675e: Preparing
# 74fb2b1f9cd0: Preparing
# a538760f4a1a: Preparing
# a5fe9a2519ae: Preparing
# ed55807831e0: Preparing
# 8629fec416c4: Preparing
# 58225d650dbb: Preparing
# 1073c0ca7301: Preparing
# be8950179889: Preparing
# 6babb56be259: Preparing
# fb5dda257106: Waiting
# a9afd6424baa: Waiting
# b2684f70a5a4: Waiting
# c1c430b6675e: Waiting
# 74fb2b1f9cd0: Waiting
# a538760f4a1a: Waiting
# 58225d650dbb: Waiting
# a5fe9a2519ae: Waiting
# 1073c0ca7301: Waiting
# ed55807831e0: Waiting
# 8629fec416c4: Waiting
# be8950179889: Waiting
# 6babb56be259: Waiting
# 4f16a913b5a6: Pushed
# 182b9829a170: Pushed
# 1e7ce649d2bc: Pushed
# b6223d9220d5: Pushed
# fb5dda257106: Pushed
# a9afd6424baa: Pushed
# b2684f70a5a4: Pushed
# c1c430b6675e: Pushed
# 74fb2b1f9cd0: Pushed
# a538760f4a1a: Pushed
# a5fe9a2519ae: Pushed
# ed55807831e0: Pushed
# 58225d650dbb: Pushed
# 1073c0ca7301: Pushed
# 6babb56be259: Pushed
# 8629fec416c4: Pushed
# be8950179889: Pushed
# 29edf9db0f9b: Pushed
# 1: digest: sha256:9d53172ae0f2f2d3e57fde6be3216d80963e37915e9e72a29eef8c00f54d225b size: 4099
# 2021/10/21 19:49:09 Successfully pushed image: c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:1
# 2021/10/21 19:49:09 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/21 19:49:09 Pushing image: c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:latest, attempt 1
# The push refers to repository [c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c]
# 182b9829a170: Preparing
# 1e7ce649d2bc: Preparing
# b6223d9220d5: Preparing
# 4f16a913b5a6: Preparing
# 29edf9db0f9b: Preparing
# fb5dda257106: Preparing
# a9afd6424baa: Preparing
# b2684f70a5a4: Preparing
# c1c430b6675e: Preparing
# 74fb2b1f9cd0: Preparing
# a538760f4a1a: Preparing
# a5fe9a2519ae: Preparing
# ed55807831e0: Preparing
# 8629fec416c4: Preparing
# 58225d650dbb: Preparing
# 1073c0ca7301: Preparing
# be8950179889: Preparing
# 6babb56be259: Preparing
# fb5dda257106: Waiting
# a9afd6424baa: Waiting
# b2684f70a5a4: Waiting
# ed55807831e0: Waiting
# c1c430b6675e: Waiting
# 8629fec416c4: Waiting
# 58225d650dbb: Waiting
# 74fb2b1f9cd0: Waiting
# 1073c0ca7301: Waiting
# a538760f4a1a: Waiting
# a5fe9a2519ae: Waiting
# be8950179889: Waiting
# 29edf9db0f9b: Layer already exists
# b6223d9220d5: Layer already exists
# 4f16a913b5a6: Layer already exists
# 1e7ce649d2bc: Layer already exists
# b2684f70a5a4: Layer already exists
# c1c430b6675e: Layer already exists
# 74fb2b1f9cd0: Layer already exists
# a538760f4a1a: Layer already exists
# a5fe9a2519ae: Layer already exists
# 182b9829a170: Layer already exists
# ed55807831e0: Layer already exists
# 58225d650dbb: Layer already exists
# 8629fec416c4: Layer already exists
# 6babb56be259: Layer already exists
# be8950179889: Layer already exists
# 1073c0ca7301: Layer already exists
# fb5dda257106: Layer already exists
# a9afd6424baa: Layer already exists
# latest: digest: sha256:9d53172ae0f2f2d3e57fde6be3216d80963e37915e9e72a29eef8c00f54d225b size: 4099
# 2021/10/21 19:49:11 Successfully pushed image: c872935793314557aea7f994311d847d.azurecr.io/azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c:latest
# 2021/10/21 19:49:11 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 110.683152)
# 2021/10/21 19:49:11 Populating digests for step ID: acb_step_0...
# 2021/10/21 19:49:12 Successfully populated digests for step ID: acb_step_0
# 2021/10/21 19:49:12 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 87.127403)
# 2021/10/21 19:49:12 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.065116)
# 2021/10/21 19:49:12 The following dependencies were found:
# 2021/10/21 19:49:12
# - image:
#     registry: c872935793314557aea7f994311d847d.azurecr.io
#     repository: azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c
#     tag: latest
#     digest: sha256:9d53172ae0f2f2d3e57fde6be3216d80963e37915e9e72a29eef8c00f54d225b
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210922.v1
#     digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#   git: {}
# - image:
#     registry: c872935793314557aea7f994311d847d.azurecr.io
#     repository: azureml/azureml_d877a17a81cc02ebe8e19d524ed5450c
#     tag: "1"
#     digest: sha256:9d53172ae0f2f2d3e57fde6be3216d80963e37915e9e72a29eef8c00f54d225b
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210922.v1
#     digest: sha256:bfed4edd2085c7fa221827c7ea4d1dc8c48fd52d64b9411260bf94f7f6fae31a
#   git: {}
#
#
# Run ID: cx9 was successful after 3m25s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e8dfb1ee97ef4d66434e02d4b73a643ecfedd1cf76fa16b75950d3bf37fa5872_d.txt
# ========================================================================================================================
# 2021-10-21T19:53:26Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24758 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-21T19:53:26Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/mounts/workspaceblobstore
# 2021-10-21T19:53:26Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-21T19:53:26Z Starting output-watcher...
# 2021-10-21T19:53:26Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
#
# Streaming azureml-logs/55_azureml-execution-tvmps_a699204611540712e607bdce04a0de44b46f0ac4401c5076e865ed1b5c231102_d.txt
# ========================================================================================================================
# 2021-10-21T19:53:26Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24781 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-21T19:53:27Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/mounts/workspaceblobstore
# 2021-10-21T19:53:27Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-21T19:53:27Z Starting output-watcher...
# 2021-10-21T19:53:27Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_30c8b4102ff1b91d5efbf92a55b8441f
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 2d4a7041ee64: Pulling fs layer
# 9b5c830079c4: Pulling fs layer
# 339038bcce95: Pulling fs layer
# c691bda31596: Pulling fs layer
# 5050e24af0d7: Pulling fs layer
# 87ce02e9f0c4: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 2d4a7041ee64: Waiting
# 9b13f06a8eff: Waiting
# 9b5c830079c4: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 339038bcce95: Waiting
# c691bda31596: Waiting
# 87ce02e9f0c4: Waiting
# 5050e24af0d7: Waiting
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 2d4a7041ee64: Verifying Checksum
# 2d4a7041ee64: Download complete
# 339038bcce95: Download complete
# c691bda31596: Verifying Checksum
# c691bda31596: Download complete
# 5050e24af0d7: Verifying Checksum
# 5050e24af0d7: Download complete
# 87ce02e9f0c4: Verifying Checksum
# 87ce02e9f0c4: Download complete
# 9b5c830079c4: Verifying Checksum
# 9b5c830079c4: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_a699204611540712e607bdce04a0de44b46f0ac4401c5076e865ed1b5c231102_d.txt
# ===============================================================================================================
# [2021-10-21T19:53:56.973621] Entering job preparation.
# [2021-10-21T19:53:57.506719] Starting job preparation.
# [2021-10-21T19:53:57.506751] Extracting the control code.
# [2021-10-21T19:53:57.507103] Starting extract_project.
# [2021-10-21T19:53:57.507167] Starting to extract zip file.
# [2021-10-21T19:53:57.530473] Finished extracting zip file.
# [2021-10-21T19:53:57.534077] Using urllib.request Python 3.0 or later
# [2021-10-21T19:53:57.534119] Start fetching snapshots.
# [2021-10-21T19:53:57.534152] Start fetching snapshot.
# [2021-10-21T19:53:57.534166] Retrieving project from snapshot: 8f376286-e340-450b-9149-be95b66d5047
# Starting the daemon thread to refresh tokens in background for process with pid = 52
# [2021-10-21T19:53:57.854804] Finished fetching snapshot.
# [2021-10-21T19:53:57.854840] Start fetching snapshot.
# [2021-10-21T19:53:57.854860] Retrieving project from snapshot: ffdaadd9-3cad-4a84-b618-2a6a60c34219
# [2021-10-21T19:54:05.565938] Finished fetching snapshot.
# [2021-10-21T19:54:05.565972] Finished fetching snapshots.
# [2021-10-21T19:54:05.565994] Finished extract_project.
# [2021-10-21T19:54:05.566147] Finished fetching and extracting the control code.
# [2021-10-21T19:54:05.572427] Start run_history_prep.
# [2021-10-21T19:54:05.578917] Job preparation is complete.
# [2021-10-21T19:54:05.579174] Entering Data Context Managers in Sidecar
# [2021-10-21T19:54:05.579983] Running Sidecar prep cmd...
# [2021-10-21T19:54:05.910167] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/azureml/138324b9-f103-49a8-8c6b-028cebef89bd
# [2021-10-21T19:54:05.910841] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2021-10-21T19:54:06.066] Enter __enter__ of DatasetContextManager
# [2021-10-21T19:54:06.067] SDK version: azureml-core==1.33.0.post1 azureml-dataprep==2.22.2. Session id: d6a47130-38db-443f-8ecf-f2bd27a3929c. Run id: 138324b9-f103-49a8-8c6b-028cebef89bd.
# [2021-10-21T19:54:06.067] Processing 'diabetes_batch'.
# [2021-10-21T19:54:06.067] Mode: 'mount'.
# [2021-10-21T19:54:06.067] Path on compute is specified: 'False'.
# [2021-10-21T19:54:08.390] Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "7381901e-6b6a-4816-9341-376cbdd9e579",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='workspace1', subscription_id='e5e390c6-3c07-4a67-b520-c6c8b11f8c47', resource_group='resgrp1')"
#   }
# }
# [2021-10-21T19:54:10.129] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579 as folder.
# [2021-10-21T19:54:10.129] Processing 'inferences'.
# [2021-10-21T19:54:10.129] Mode: 'mount'.
# [2021-10-21T19:54:10.129] Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore'.
# [2021-10-21T19:54:10.883] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579.
# [2021-10-21T19:54:10.883] Mounting inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore.
# [2021-10-21T19:54:15.982] Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore.
# [2021-10-21T19:54:15.982] Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579.
# [2021-10-21T19:54:16.001] Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579
# Set OutputDataset inferences's target path to /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore
# [2021-10-21T19:54:16.002035] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-10-21T19:54:16.404665] Ran Sidecar prep cmd.
# [2021-10-21T19:54:16.405207] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/10/21 19:54:54 Got JobInfoJson from env
# 2021/10/21 19:54:54 Starting App Insight Logger for task:  runTaskLet
# 2021/10/21 19:54:54 Version: 3.0.01744.0001 Branch: .SourceBranch Commit: f3a69a2
# 2021/10/21 19:54:54 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/10/21 19:54:54 Send process info logs to master server succeeded
# 2021/10/21 19:54:54 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/10/21 19:54:54 Send process info logs to master server succeeded
# [2021-10-21T19:54:54.442500] Entering context manager injector.
# [2021-10-21T19:54:54.880963] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.35.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-10-21T19:54:54.884584] Entering Run History Context Manager.
# [2021-10-21T19:54:55.500508] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/azureml/138324b9-f103-49a8-8c6b-028cebef89bd
# [2021-10-21T19:54:55.500765] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.35.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'diabetes_batch']
# [2021-10-21T19:54:55.500794] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.35.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore', '--input_fds_0', 'diabetes_batch']
#
# 2021/10/21 19:54:59 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2021-10-21T19:55:39.658975] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
# Cleanup took 0.1943950653076172 seconds
# [2021-10-21T19:55:39.990930] Finished context manager injector.
# 2021/10/21 19:55:40 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/10/21 19:55:40 Send process info logs to master server succeeded
# 2021/10/21 19:55:40 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/10/21 19:55:40 Process Exiting with Code:  0
# 2021/10/21 19:55:41 All App Insights Logs was sent successfully or the close timeout of 10 was reached
#
# Streaming azureml-logs/75_job_post-tvmps_a699204611540712e607bdce04a0de44b46f0ac4401c5076e865ed1b5c231102_d.txt
# ===============================================================================================================
# [2021-10-21T19:55:42.886968] Entering job release
# [2021-10-21T19:55:43.575258] job release stage : copy_batchai_cached_logs starting...
# [2021-10-21T19:55:43.575351] job release stage : copy_batchai_cached_logs completed...
# [2021-10-21T19:55:43.575523] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-10-21T19:55:43.575950] Running Sidecar release cmd...
# [2021-10-21T19:55:43.584149] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/azureml/138324b9-f103-49a8-8c6b-028cebef89bd
# [2021-10-21T19:55:43.589] Enter __exit__ of DatasetContextManager
# [2021-10-21T19:55:43.589] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579: No such file or directory
# [2021-10-21T19:55:43.613] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/diabetes_batch_7381901e-6b6a-4816-9341-376cbdd9e579.
# [2021-10-21T19:55:43.613] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore.
# [2021-10-21T19:55:43.623] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/workspace1/azureml/138324b9-f103-49a8-8c6b-028cebef89bd/wd/inferences_workspaceblobstore.
# [2021-10-21T19:55:43.623] Exit __exit__ of DatasetContextManager
# [2021-10-21T19:55:43.623721] Removing absolute paths from host...
# [2021-10-21T19:55:43.623955] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-10-21T19:55:44.356571] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '138324b9-f103-49a8-8c6b-028cebef89bd', 'target': 'compcluster1', 'status': 'Completed', 'startTimeUtc': '2021-10-21T19:53:22.214336Z', 'endTimeUtc': '2021-10-21T19:55:55.701697Z', 'services': {}, 'properties': {'ContentSnapshotId': '8f376286-e340-450b-9149-be95b66d5047', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '4e9c97b8-a752-48ca-b6df-22fbdb9fd33a', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'c2aed05f', 'azureml.pipelinerunid': '32fb58b5-bb67-4a9a-adff-905e0166f4f5', 'azureml.pipeline': '32fb58b5-bb67-4a9a-adff-905e0166f4f5', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '7381901e-6b6a-4816-9341-376cbdd9e579'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '453d8acd-d467-4d0c-a1b8-6e514779578b'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/138324b9-f103-49a8-8c6b-028cebef89bd/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "453d8acd-d467-4d0c-a1b8-6e514779578b",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='workspace1', subscription_id='e5e390c6-3c07-4a67-b520-c6c8b11f8c47', resource_group='resgrp1')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.35.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'compcluster1', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '7381901e-6b6a-4816-9341-376cbdd9e579', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2021-10-21T19:45:44Z_e78961b0', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}], 'name': 'azureml_e220b045f6c3c3008b1a386af067185d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210922.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': [], 'dataBricks': {'workers': 0, 'minimumWorkerCount': 0, 'maxMumWorkerCount': 0, 'sparkVersion': '4.0.x-scala2.11', 'nodeTypeId': 'Standard_D3_v2', 'sparkConf': {}, 'sparkEnvVars': {}, 'instancePoolId': None, 'timeoutSecon ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '32fb58b5-bb67-4a9a-adff-905e0166f4f5', 'status': 'Completed', 'startTimeUtc': '2021-10-21T19:45:40.585755Z', 'endTimeUtc': '2021-10-21T19:55:57.387374Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.32fb58b5-bb67-4a9a-adff-905e0166f4f5/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=3PkSqAPnUd7EeIRA1OMnG%2BKwSs1wKplGZHvvTKAfwtI%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A01Z&se=2021-10-22T03%3A56%3A01Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.32fb58b5-bb67-4a9a-adff-905e0166f4f5/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=JJCezJOkcGt1iZleXQv4sHyLnGIX7rBwxUJdaSkgyQU%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A01Z&se=2021-10-22T03%3A56%3A01Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.32fb58b5-bb67-4a9a-adff-905e0166f4f5/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=nTYAEnsNONhDOmH8GUGpTiPPALqtaJl8gt3Sd7L3P4k%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A01Z&se=2021-10-22T03%3A56%3A01Z&sp=r'}, 'submittedBy': 'Richard K'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           0
# 4    12.csv           0
# 5    13.csv           1
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           0
# 10   18.csv           0
# 11   19.csv           1
# 12    2.csv           1
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           1
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           1

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 64073bf9-11d0-4587-bc1b-7557d63913ba,
# Status: Active,
# Endpoint: https://canadacentral.api.azureml.ms/pipelines/v1.0/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourceGroups/resgrp1/providers/Microsoft.MachineLearningServices/workspaces/workspace1/PipelineRuns/PipelineSubmit/64073bf9-11d0-4587-bc1b-7557d63913ba)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://canadacentral.api.azureml.ms/pipelines/v1.0/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourceGroups/resgrp1/providers/Microsoft.MachineLearningServices/workspaces/workspace1/PipelineRuns/PipelineSubmit/64073bf9-11d0-4587-bc1b-7557d63913ba

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# 'be72c25c-79d1-4418-a56f-da329d692c1f'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: be72c25c-79d1-4418-a56f-da329d692c1f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/be72c25c-79d1-4418-a56f-da329d692c1f?wsid=/subscriptions/e5e390c6-3c07-4a67-b520-c6c8b11f8c47/resourcegroups/resgrp1/workspaces/workspace1&tid=378009d7-cd7a-4659-9bbc-c3eae57b738b
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'be72c25c-79d1-4418-a56f-da329d692c1f', 'status': 'Completed', 'startTimeUtc': '2021-10-21T19:56:12.633154Z', 'endTimeUtc': '2021-10-21T19:56:14.480364Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelineid': '64073bf9-11d0-4587-bc1b-7557d63913ba'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.be72c25c-79d1-4418-a56f-da329d692c1f/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=oA1gtuEGIagAA1g9QgQ%2F1biPGyUt6sU58UiNctkaylU%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A16Z&se=2021-10-22T03%3A56%3A16Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.be72c25c-79d1-4418-a56f-da329d692c1f/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=w27oME2%2Fhv7WRMDjQweoxnV8jnPqlDDZ1qBVUF6pdIY%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A16Z&se=2021-10-22T03%3A56%3A16Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://workspace14887054496.blob.core.windows.net/azureml/ExperimentRun/dcid.be72c25c-79d1-4418-a56f-da329d692c1f/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=ttEFl4AswR4eF3a3V%2BNbIxKISOdtsCLcMSHdvwWq0dg%3D&skoid=e793d80a-df03-423d-bf88-fb7b60329581&sktid=378009d7-cd7a-4659-9bbc-c3eae57b738b&skt=2021-10-21T16%3A54%3A58Z&ske=2021-10-23T01%3A04%3A58Z&sks=b&skv=2019-07-07&st=2021-10-21T19%3A46%3A16Z&se=2021-10-22T03%3A56%3A16Z&sp=r'}, 'submittedBy': 'Richard K'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           0
# 4    12.csv           0
# 5    13.csv           1
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           0
# 10   18.csv           0
# 11   19.csv           1
# 12    2.csv           1
# 13   20.csv           1
# 14   21.csv           0
# 15   22.csv           1
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           1

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
